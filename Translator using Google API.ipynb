# %%
import pandas as pd
import numpy as np

# %%
from googletrans import Translator

# %%
def translate_text_googletrans(str):
    translator = Translator()
    return translator.translate(str).text

# %%
df  = pd.read_excel('file.xlsx',sheetname='Sheet1')
# Out:
# C:\Users\humay\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
df.head()
# Out:
#                                                  A  \
# 0  Low Blood Pressure And Hypotension Question\n\n
# 1    Low Blood Pressure And Hypotension Question\n
# 2    Low Blood Pressure And Hypotension Question\n
# 3                             Low Blood Pressure\n
# 4            Low Blood Pressure After I Eat Meat\n
#
#                                                  B_T  \
# 0  Hi, at night when I fall asleep suddenly I am ...
# 1  I have low blood pressure and a high heart rat...
# 2  I am a 36 yo female. I am 5.2 135 lbs. I dont ...
# 3  Is there such a thing as blood pressure that i...
# 4  I`m 35 year old male. 180 cm high, 87 kg. Sinc...
#
#                                                    T
# 0  "Hola, en la noche, cuando me duermo de repent...
# 1  "Tengo presión arterial baja y un ritmo cardía...
# 2  "Soy una mujer de 36 años. Tengo 5.2 135 libra...
# 3  "¿Existe una presión arterial demasiado baja? ...
# 4  "Soy un hombre de 35 años. 180 cm de alto, 87 ...

# %%
df.dtypes
# Out:
# A      object
# B_T    object
# T      object
# dtype: object

# %%
def translate_text(str1):
        translated_text = translate_text_googletrans(str1)
        return translated_text

# %%
df['A_T']=df['T'].astype(str).apply(translate_text)

# %%
import copy
translatedList = []
for index, row in df.iterrows():
    # REINITIALIZE THE API
    translator = Translator()
    newrow = copy.deepcopy(row)
    try:
        # translate the 'text' column
        translated = translator.translate('text', dest='en')
        newrow['translated'] = translated.text
    except Exception as e:
        print(str(e))
        continue
    translatedList.append(newrow)

# %%
from googletrans import Translator
translator = Translator()
text = translator.translate('text', src='en', dest='ru')
print(text.text)
# Out:
# текст

# %%
df.head()
# Out:
#                                                  A  \
# 0  Low Blood Pressure And Hypotension Question\n\n
# 1    Low Blood Pressure And Hypotension Question\n
# 2    Low Blood Pressure And Hypotension Question\n
# 3                             Low Blood Pressure\n
# 4            Low Blood Pressure After I Eat Meat\n
#
#                                                  B_T  \
# 0  Hi, at night when I fall asleep suddenly I am ...
# 1  I have low blood pressure and a high heart rat...
# 2  I am a 36 yo female. I am 5.2 135 lbs. I dont ...
# 3  Is there such a thing as blood pressure that i...
# 4  I`m 35 year old male. 180 cm high, 87 kg. Sinc...
#
#                                                    T  \
# 0  "Hola, en la noche, cuando me duermo de repent...
# 1  "Tengo presión arterial baja y un ritmo cardía...
# 2  "Soy una mujer de 36 años. Tengo 5.2 135 libra...
# 3  "¿Existe una presión arterial demasiado baja? ...
# 4  "Soy un hombre de 35 años. 180 cm de alto, 87 ...
#
#                                                  A_T
# 0  "Hello, in the night, when I suddenly fall asl...
# 1  "I have low blood pressure and a high heart ra...
# 2  "I'm a 36-year-old woman, I'm 5.2 135 pounds, ...
# 3  "Is my blood pressure too low?" My blood press...
# 4  "I am a 35 year old man, 180 cm tall, 87 kg, a...

# %%
translatedList
# Out:
# [A               Low Blood Pressure And Hypotension Question\n\n
#  B_T           Hi, at night when I fall asleep suddenly I am ...
#  T             "Hola, en la noche, cuando me duermo de repent...
#  A_T           Hi, at night when I fall asleep suddenly I am ...
#  translated                                                 text
#  Name: 0, dtype: object,
#  A                 Low Blood Pressure And Hypotension Question\n
#  B_T           I have low blood pressure and a high heart rat...
#  T             "Tengo presión arterial baja y un ritmo cardía...
#  A_T           I have low blood pressure and a high heart rat...
#  translated                                                 text
#  Name: 1, dtype: object,
#  A                 Low Blood Pressure And Hypotension Question\n
#  B_T           I am a 36 yo female. I am 5.2 135 lbs. I dont ...
#  T             "Soy una mujer de 36 años. Tengo 5.2 135 libra...
#  A_T           I am a 36 yo female. I am 5.2 135 lbs. I dont ...
#  translated                                                 text
#  Name: 2, dtype: object,
#  A                                          Low Blood Pressure\n
#  B_T           Is there such a thing as blood pressure that i...
#  T             "¿Existe una presión arterial demasiado baja? ...
#  A_T           Is there such a thing as blood pressure that i...
#  translated                                                 text
#  Name: 3, dtype: object,
#  A                         Low Blood Pressure After I Eat Meat\n
#  B_T           I`m 35 year old male. 180 cm high, 87 kg. Sinc...
#  T             "Soy un hombre de 35 años. 180 cm de alto, 87 ...
#  A_T           I`m 35 year old male. 180 cm high, 87 kg. Sinc...
#  translated                                                 text
#  Name: 4, dtype: object,
#  A                             Treating Orthostatic Hypotension
#  B_T           My mother entered the hospital 39 days ago due...
#  T                                                           NaN
#  A_T           My mother entered the hospital 39 days ago due...
#  translated                                                 text
#  Name: 5, dtype: object,
#  A                               Ways To Stop Syncope Epidsode\n
#  B_T           Does anyone know of ways to stop the loss of c...
#  T                                                           NaN
#  A_T           Does anyone know of ways to stop the loss of c...
#  translated                                                 text
#  Name: 6, dtype: object,
#  A                     Syncope : Bodily Movement And Open Eyes\n
#  B_T           I have suffered from fainting spells most of m...
#  T                                                           NaN
#  A_T           I have suffered from fainting spells most of m...
#  translated                                                 text
#  Name: 7, dtype: object,
#  A                              Symptoms Of Low Blood Pressure\n
#  B_T           Hi there. \nIn my family, there is a heredity ...
#  T                                                           NaN
#  A_T           Hi there. \nIn my family, there is a heredity ...
#  translated                                                 text
#  Name: 8, dtype: object,
#  A                          Low Blood Pressure And Weight Gain\n
#  B_T           I have been on blood pressure medicine for yea...
#  T                                                           NaN
#  A_T           I have been on blood pressure medicine for yea...
#  translated                                                 text
#  Name: 9, dtype: object,
#  A                                           Hypotension At 17\n
#  B_T           i have high blood pressure and hypotension \na...
#  T                                                           NaN
#  A_T           i have high blood pressure and hypotension \na...
#  translated                                                 text
#  Name: 10, dtype: object,
#  A                                       Blood Pressure Number\n
#  B_T           I have a blood pressure of 194 / 113 with a pu...
#  T                                                           NaN
#  A_T           I have a blood pressure of 194 / 113 with a pu...
#  translated                                                 text
#  Name: 11, dtype: object,
#  A                                 Blood Pressure Bottomed Out\n
#  B_T           what could cause bloodpressure to bottom out, ...
#  T                                                           NaN
#  A_T           what could cause bloodpressure to bottom out, ...
#  translated                                                 text
#  Name: 12, dtype: object,
#  A                          High Diastolic And Normal Systolic\n
#  B_T           Hello. I just had a question about blood press...
#  T                                                           NaN
#  A_T           Hello. I just had a question about blood press...
#  translated                                                 text
#  Name: 13, dtype: object,
#  A                Hypotension , Steady Heart Rate , Chest Pain\n
#  B_T           Here's one for you. It's not me, it's my girlf...
#  T                                                           NaN
#  A_T           Here's one for you. It's not me, it's my girlf...
#  translated                                                 text
#  Name: 14, dtype: object,
#  A                                          Low Blood Pressure\n
#  B_T           Ok my bp runs low for about 3.5 years now. It ...
#  T                                                           NaN
#  A_T           Ok my bp runs low for about 3.5 years now. It ...
#  translated                                                 text
#  Name: 15, dtype: object,
#  A                              Sudden Drop In Blood Pressure?\n
#  B_T           I've recently been diagnosed with chronic hypo...
#  T                                                           NaN
#  A_T           I've recently been diagnosed with chronic hypo...
#  translated                                                 text
#  Name: 16, dtype: object,
#  A             Can Low Blood Pressure Result From Eating Afte...
#  B_T           I've had constant low blood pressure for years...
#  T                                                           NaN
#  A_T           I've had constant low blood pressure for years...
#  translated                                                 text
#  Name: 17, dtype: object,
#  A                        Hypotention, Bpm, My Life Is On Hold\n
#  B_T           hypotention, bpm, symptoms with mine the heada...
#  T                                                           NaN
#  A_T           hypotention, bpm, symptoms with mine the heada...
#  translated                                                 text
#  Name: 18, dtype: object,
#  A             Blood Pressure Continually Declining And Worse...
#  B_T           Normally, my blood pressure has always been ar...
#  T                                                           NaN
#  A_T           Normally, my blood pressure has always been ar...
#  translated                                                 text
#  Name: 19, dtype: object,
#  A                            Hypotension / Low Blood Pressure\n
#  B_T           In reading about carbohydrate restricted diets...
#  T                                                           NaN
#  A_T           In reading about carbohydrate restricted diets...
#  translated                                                 text
#  Name: 20, dtype: object,
#  A                            Ortho-Static Hypotension Or Not?\n
#  B_T           I was diagnosed with ortho-static hypotension ...
#  T                                                           NaN
#  A_T           I was diagnosed with ortho-static hypotension ...
#  translated                                                 text
#  Name: 21, dtype: object,
#  A             Blood Pressure Continually Declining And Worse...
#  B_T           Normally, my blood pressure has always been ar...
#  T                                                           NaN
#  A_T           Normally, my blood pressure has always been ar...
#  translated                                                 text
#  Name: 22, dtype: object,
#  A                       No Carbs., Dizzy And Nausious, Low Bp\n
#  B_T           I went to bed late last night and i am on the ...
#  T                                                           NaN
#  A_T           I went to bed late last night and i am on the ...
#  translated                                                 text
#  Name: 23, dtype: object,
#  A                                         Fainting, Dizziness\n
#  B_T           Today my 12 year old daughter fainted and she ...
#  T                                                           NaN
#  A_T           Today my 12 year old daughter fainted and she ...
#  translated                                                 text
#  Name: 24, dtype: object,
#  A                              Sudden Drop In Blood Pressure?\n
#  B_T           I've recently been diagnosed with chronic hypo...
#  T                                                           NaN
#  A_T           I've recently been diagnosed with chronic hypo...
#  translated                                                 text
#  Name: 25, dtype: object,
#  A             Low Blood Pressure While Exercising, An Underl...
#  B_T           I found these posts a few yrs. ago when I was ...
#  T                                                           NaN
#  A_T           I found these posts a few yrs. ago when I was ...
#  translated                                                 text
#  Name: 26, dtype: object,
#  A                              Blood Pressure Unusual Pattern\n
#  B_T           I have a question to which I have yet to get t...
#  T                                                           NaN
#  A_T           I have a question to which I have yet to get t...
#  translated                                                 text
#  Name: 27, dtype: object,
#  A                 Fatigue,Confused, Bp Low ,Memory Impairment\n
#  B_T           i usually feel fatigue aftr doing smal works l...
#  T                                                           NaN
#  A_T           i usually feel fatigue aftr doing smal works l...
#  translated                                                 text
#  Name: 28, dtype: object,
#  A                      Father Has A Problem With His Tension,\n
#  B_T           Hope someone help, my father has a problem wit...
#  T                                                           NaN
#  A_T           Hope someone help, my father has a problem wit...
#  translated                                                 text
#  Name: 29, dtype: object,
#  A                          Hypotension...Should I Be Worried?\n
#  B_T           I have recently been told that I have hypotens...
#  T                                                           NaN
#  A_T           I have recently been told that I have hypotens...
#  translated                                                 text
#  Name: 30, dtype: object,
#  A                              Low Blood Pressure, Chest Pain\n
#  B_T           Doctors baffled, 2 years ago I had a stent put...
#  T                                                           NaN
#  A_T           Doctors baffled, 2 years ago I had a stent put...
#  translated                                                 text
#  Name: 31, dtype: object,
#  A                           Suffering From Low Blood Pressure\n
#  B_T           i have 46 year old male employee that is suffe...
#  T                                                           NaN
#  A_T           i have 46 year old male employee that is suffe...
#  translated                                                 text
#  Name: 32, dtype: object,
#  A                            Hypotension (Low BP) & Shaking??\n
#  B_T           I have been under a lot of stress recently and...
#  T                                                           NaN
#  A_T           I have been under a lot of stress recently and...
#  translated                                                 text
#  Name: 33, dtype: object,
#  A                       Blood Pressure Medicine / Urine Smell\n
#  B_T           i am having low blood pressure. now, i am cons...
#  T                                                           NaN
#  A_T           i am having low blood pressure. now, i am cons...
#  translated                                                 text
#  Name: 34, dtype: object,
#  A             Fatigue-After Doing Anything I Feel Like I've ...
#  B_T           I have a type of fatigue whenever I do any typ...
#  T                                                           NaN
#  A_T           I have a type of fatigue whenever I do any typ...
#  translated                                                 text
#  Name: 35, dtype: object,
#  A             Sudden Drop In Blood Pressure, Emergency Home ...
#  B_T           what emergency home treatment for sudden drop ...
#  T                                                           NaN
#  A_T           what emergency home treatment for sudden drop ...
#  translated                                                 text
#  Name: 36, dtype: object,
#  A             When Is Low Blood Pressure Considered A Proble...
#  B_T           I am a 39 year old female. Can anyone tell me ...
#  T                                                           NaN
#  A_T           I am a 39 year old female. Can anyone tell me ...
#  translated                                                 text
#  Name: 37, dtype: object,
#  A                              Dizziness And Chest Discomfort\n
#  B_T           I am experiencing dizziness, headches and ches...
#  T                                                           NaN
#  A_T           I am experiencing dizziness, headches and ches...
#  translated                                                 text
#  Name: 38, dtype: object,
#  A                                         Low Blood Preasure.\n
#  B_T           Low B.P.is a common problem but seen as less i...
#  T                                                           NaN
#  A_T           Low B.P.is a common problem but seen as less i...
#  translated                                                 text
#  Name: 39, dtype: object]
